# %% [markdown]
# <a href="https://colab.research.google.com/github/SIT-COMP-1210/module2-breakout-leulakassahun/blob/main/module2_breakout.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/SIT-COMP-1210/Module2-Breakout-leulakassahun.git
# Out:
# fatal: destination path 'Module2-Breakout-leulakassahun' already exists and is not an empty directory.

# %% [markdown]
# **Data Types and Arithmetic Operators Exercise**

# %% [markdown]
# 1. What is the type of 2?

# %%
type(2)
# Out:
# int

# %% [markdown]
# 2. What is the type of 2.0?

# %%
type(2.0)
# Out:
# float

# %% [markdown]
# 3. What is the resulting type of adding 2 and 2?

# %%
print(2+2)
# Out:
# 4

# %% [markdown]
# 4. What is the type of ‘Programming’ ?

# %%
type('Programming')
# Out:
# str

# %% [markdown]
# 5. What is the resulting output when you add ‘Programming’ and ‘Computer’?

# %%
print('Programming'+'Computer')
# Out:
# ProgrammingComputer

# %% [markdown]
# 6. What is the result of ‘Ethiopia’ * 3 ?

# %%
print('Ethiopia'*3)
# Out:
# EthiopiaEthiopiaEthiopia

# %% [markdown]
# 7. What is the result of 10.0 * 7?

# %%
print(10.0*7)
# Out:
# 70.0

# %% [markdown]
# 8. What is stored in result?

# %%
result = str(int(2.8))

print(result)
# Out:
# 2

# %% [markdown]
# 9. What is the final value and type of x?

# %%
x = int(float(-5))

print(x)
type(x)
# Out:
# -5
# int

# %% [markdown]
# 10. What is stored in expr? What is the order of operations?

# %%
expr = "a" + "b" * 2 + "c"

print(expr)

#First it will multiply "b" by 2 and then add "a", "bb" and "c"
# Out:
# abbc

# %% [markdown]
# 11. What is the final value of value?

# %%
value = 100 / 5 // 4 * 3 % 5

print(value)
# Out:
# 0.0

# %% [markdown]
# 12. hat is the value of b? Why does this happen?

# %%
b = bool(0)
print(b)

#Because python's boolean works like a logic gate where 1 is True and 0 is False.
# Out:
# False

# %% [markdown]
# 13. Why are the results numerically the same but types different?

# %%
a = 4 * 3
b = 4 * 3.0

print(a)
print(b)

print(type(a))
print(type(b))

#The results are different because python interpret the two as different equation making them different like float and integer
# Out:
# 12
# 12.0
# <class 'int'>
# <class 'float'>

# %% [markdown]
# 14. Does calling int() on an int or float() on a float change the value? Why or why not?

# %%
x = int(5)
y = float(5.0)

int(x)
float(y)

#No it won't change the value, because calling int() on an int or float() on a float is like calling oneself again and again
# Out:
# 5

# %% [markdown]
# 15. What is the value and type of x?

# %%
x = 2 ** 3

print(x)
type(x)
# Out:
# 8
# int

# %% [markdown]
# 16. What is the value of y?

# %%
y = 4 * 2 ** 2

print(y)
# Out:
# 16

# %% [markdown]
# 17. What is the value of a?

# %%
a = 5 - 1 + 4 * 2
print(a)
# Out:
# 12

# %% [markdown]
# 18. What is the value of b?

# %%
b = (5 - 1 + 4) * 2
print(b)
# Out:
# 16

# %% [markdown]
# 19. What are the values of b1 and b2? Are they the same? If not, why are they different?

# %%
b1 = bool("")
b2 = bool("False")

print(b1)
print(b2)

#b1 is empty which python interprets it as 0, but b2 has string inside it which is interpreted as 1
# Out:
# False
# True

# %% [markdown]
# 20. Is (2 + 3) * 4 an expression or a function?

# %%
# It is an expression, because an expression is made up of values and operators

# %% [markdown]
# 21. What is the final value of result?

# %%
result = str(int(5.9) + 2 ** 2) * 2

print(result)
# Out:
# 99
